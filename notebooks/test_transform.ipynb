# %%
import pandas as pd

# %%
df = pd.read_csv("/home/user/leucemia/Leukemia-Cancer-Risk-ETL/data/world_bank_data.csv")
df.head()
# Out:
#        Country  Year  Agricultural irrigated land  \
# 0  Afghanistan  2000                          NaN
# 1  Afghanistan  2001                     5.662125
# 2  Afghanistan  2002                     4.617624
# 3  Afghanistan  2003                     7.264280
# 4  Afghanistan  2004                     5.499895
#
#    Electricity production from nuclear sources  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    Employment in agriculture (% of total employment)  Fertilizer consumption  \
# 0                                          65.651597              100.000000
# 1                                          65.025449              100.000000
# 2                                          64.186689              104.751559
# ...

# %%
def Read_csv(path):
    """Read csv and give to the user a pandas Dataframe"""
    return pd.read_csv(path)

# %%
def detectar_nulos(path):
    """
    Find Nulls values in a dataframe
    """
    df = pd.read_csv(path)
    return df.isnull().sum()

# %%
def Nulls_
